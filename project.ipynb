# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset and it was downloaded using web scraping techniques. The data contains registers from fotocasa which is one of the most popular websites of real estate in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro and In no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
# TODO

# mayor precio
precio_maximo = ds['price'].max()
# Fila precio maximo
fila_precio_max = ds.loc[ds['price']==precio_maximo]
 # Obtener direccion
dir_precio_max = fila_precio_max['address'].values[0]

print(f'The house with the address {dir_precio_max} is the most expensive and its price is {precio_maximo} USD')
# Out:
# The house with the address El Escorial is the most expensive and its price is 8500000 USD

# %% [markdown]
# #### Exercise 02. Which is cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
# TODO

# menor precio con precio mayor a 0
precio_minimo = ds.loc[ds['price'] > 0, 'price'].min()
# Fila precio min
fila_precio_min = ds.loc[ds['price']==precio_minimo]
 # Obtener direccion
dir_precio_min = fila_precio_min['address'].values[0]

print(f'The house with the address {dir_precio_min} is the cheapest and its price is {precio_minimo} USD')
# Out:
# The house with the address Berlin, Coslada is the cheapest and its price is 600 USD

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
# TODO
# mayor y menor tamaño
biggest = ds['surface'].max()
smallest = ds['surface'].min()
# Filas maximas y minimas
fila_biggest = ds.loc[ds['surface']==biggest]
fila_smallest = ds.loc[ds['surface']==smallest]
# Direcciones
dir_biggest = fila_biggest['address'].values[0]
dir_smallest = fila_smallest['address'].values[0]
# Imprimir mensaje
print(f"The bigger house is located in {dir_biggest} and it's surface is {biggest} meters")
print(f"The smaller house is located in {dir_biggest} and it's surface is {smallest} meters")
# Out:
# The bigger house is located in Sevilla la Nueva and it's surface is 249000.0 meters
# The smaller house is located in Sevilla la Nueva and it's surface is 15.0 meters

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the name of the populations with comma as separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
# TODO
lista_lugares = set(ds['level5'])
lista_ordenada = sorted(list(lista_lugares))
for n in lista_ordenada:
    print (n, end=', ')
# Out:
#  Madrid Capital, Ajalvir, Alcalá de Henares, Alcobendas, Alcorcón, Aldea del Fresno, Algete, Alpedrete, Ambite, Anchuelo, Aranjuez, Arganda del Rey, Arroyomolinos (Madrid), Batres, Becerril de la Sierra, Belmonte de Tajo, Boadilla del Monte, Braojos, Brea de Tajo, Brunete, Buitrago del Lozoya, Bustarviejo, Cabanillas de la Sierra, Cadalso de los Vidrios, Camarma de Esteruelas, Campo Real, Canencia, Carabaña, Casarrubuelos, Cenicientos, Cercedilla, Chapinería, Chinchón, Ciempozuelos, Cobeña, Collado Mediano, Collado Villalba, Colmenar Viejo, Colmenar de Oreja, Colmenar del Arroyo, Colmenarejo, Corpa, Coslada, Cubas de la Sagra, Daganzo de Arriba, El Atazar, El Berrueco, El Boalo - Cerceda – Mataelpino, El Escorial, El Molar (Madrid), El Vellón, El Álamo, Estremera, Fresnedillas de la Oliva, Fresno de Torote, Fresno de Torote - Serracines, Fuenlabrada, Fuente El Saz de Jarama, Fuentidueña de Tajo, Galapagar, Garganta de los Montes, Gargantilla del Lozoya, Gascones, Getafe, Griñón, Guad
# ...

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`true` or `fase`) followed by the rows/cols that contains NAs.

# %%
# TODO
revision = ds.isna().any().any()
if revision:
    print ('Si hay valores N/A')
    print("\Filas con valores faltantes:")
    filas_na = ds.index[ds.isna().any(axis=1)].tolist()
    for n in filas_na:
        print (n, end=', ')
    columnas_na = ds.columns[ds.isna().any()].tolist()
    print("\nColumnas con valores faltantes:")
    for n in columnas_na:
        print(n, end=', ')
else:
    print('No hay valores N/A')
# Out:
# Si hay valores N/A
# \Filas con valores faltantes:
# ...

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions

# %%
# TODO
ds = pd.read_csv('assets/real_estate.csv', sep=';', skiprows=[1])
print("Dimensiones antes de eliminar NAs:", ds.shape)
ds = ds.dropna(axis=1, how='all')
print("Dimensiones despues de eliminar Columnas NAs:", ds.shape)
ds = ds[~ds.apply(lambda row: row.astype(str).str.contains('NA')).any(axis=1)]
print("Dimensiones despues de eliminar Filas NAs:", ds.shape)
# Out:
# Dimensiones antes de eliminar NAs: (15334, 37)
# Dimensiones despues de eliminar Columnas NAs: (15334, 35)
# Dimensiones despues de eliminar Filas NAs: (12724, 35)

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value

# %%
# TODO
prom =int(ds[ds['level5'] == 'Arroyomolinos (Madrid)']['price'].mean())
print (prom)
# Out:
# 291066

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
# TODO: Code
import matplotlib.pyplot as plt

data = ds[ds['level5'] == 'Arroyomolinos (Madrid)']['price']
plt.figure(figsize=(10, 5))
plt.hist(data, bins=6, edgecolor='black')
plt.xlabel("Precio")
plt.ylabel("Frecuencia")
plt.title("Precio de Viviendas en Arroyomolinos")
plt.show()

# %% [markdown]
# Precion de viviendas en Arroyomolinos (Madrid).  El eje horizontal muestra los precios, mientras que el eje vertical muestra la frecuencia para cada rango de precios

# %% [markdown]
# #### Exercise 09. Is the average of "Valdemorillo" and "Galapagar" prices the same? (★★☆)
#
# Print the both average prices and then write a conclusion about them

# %%
# TODO
prom_Valdemorillo = int(ds[ds['level5'] == 'Valdemorillo']['price'].mean())
prom_Galapagar = int(ds[ds['level5'] == 'Galapagar']['price'].mean())
print (f'Precio promedio en Valdemorillo: {prom_Valdemorillo}')
print (f'Precio promedio en Galapagar: {prom_Galapagar}')
if prom_Valdemorillo == prom_Galapagar:
    print ('Ambos promedios son iguales')
else:
    print('Los precios promedio no son iguales para estas localidades')
# Out:
# Precio promedio en Valdemorillo: 342375
# Precio promedio en Galapagar: 387781
# Los precios promedio no son iguales para estas localidades

# %% [markdown]
# #### Exercise 10. Is the average of "Valdemorillo" and "Galapagar" price per square meter (price/m2) the same? (★★☆)
#
# Print the both average prices and then write a conclusion about
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# TODO
ds['precio/mt2'] = ds['price'] / ds['surface']
prom_Valdemorillo = int(ds[ds['level5'] == 'Valdemorillo']['precio/mt2'].mean())
prom_Galapagar = int(ds[ds['level5'] == 'Galapagar']['precio/mt2'].mean())
print (f'Precio promedio por mt2 en Valdemorillo: {prom_Valdemorillo}')
print (f'Precio promedio por mt2 en Galapagar: {prom_Galapagar}')
if prom_Valdemorillo == prom_Galapagar:
    print ('Ambos promedios son iguales')
else:
    print('Los precios promedio por mt2 no son iguales')
# Out:
# Precio promedio por mt2 en Valdemorillo: 1349
# Precio promedio por mt2 en Galapagar: 1599
# Los precios promedio por mt2 no son iguales

# %% [markdown]
# #### Exercise 11. Analyse the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot` and then write a conclusion about it

# %%
# TODO: Code
import matplotlib.pyplot as plt
X = ds[ds['surface']<3000]['surface']
y = ds[ds['surface']<3000]['price']
plt.figure(figsize=(10, 5))
plt.scatter(X, y)
plt.title("Gráfico de dispersión")
plt.xlabel('Surface')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# Se observa que a medida que aumenta la superficie, aumenta tanto el precio como la dispersion en los precios.

# %% [markdown]
# #### Exercise 12. How many real estate agencies the dataset contains? (★★☆)
#
# Print the obtained value

# %%
# TODO
agencias = len(ds['realEstate_name'].unique())
print(f"Cantidad de Agencias': {agencias}")
# Out:
# Cantidad de Agencias': 1654

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses

# %%
# TODO
frecuencia_casas = ds['level5'].value_counts()
poblacion_max = frecuencia_casas.idxmax()
frecuencia_max = frecuencia_casas.max()
print(f'La Poblacion con mas casas es {poblacion_max} con un total de {frecuencia_max} casas')
# Out:
# La Poblacion con mas casas es  Madrid Capital con un total de 5793 casas

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`

# %%
# TODO
sb = ["Fuenlabrada","Leganés","Getafe","Alcorcón"]
sb_ds = ds[ds['level5'].isin(sb)]

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in the question 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot

# %%
# TODO: Code
precios_prom = sb_ds.groupby('level5')['price'].mean()
precios_prom = precios_prom.round().astype(int).sort_values(ascending= False)
'''print (precios_prom)'''

plt.figure(figsize = (10, 5))
plt.bar(precios_prom.index, precios_prom)
plt.title("Precio Promedio por Localidad")
plt.xlabel("Localidad")
plt.ylabel("Precio Promedio")
plt.show()

# %% [markdown]
# Getafe presenta el precio promedio de precios mas alto, seguido por Alcorcon, Leganes y Fuenlabrada

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in the question 14) (★★★)
#
# Print both values for each variable

# %%
# TODO
datos = ['price', 'rooms', 'surface', 'bathrooms']
for columna in datos:
    promedio = int(sb_ds[columna].mean())
    varianza = sb_ds[columna].var().round(2)
    print(f'El promedio de {columna} es: {promedio}')
    print(f'La Varianza de {columna} es: {varianza}')
# Out:
# El promedio de price es: 228229
# La Varianza de price es: 15236541434.51
# El promedio de rooms es: 3
# La Varianza de rooms es: 0.76
# El promedio de surface es: 110
# La Varianza de surface es: 3378.7
# El promedio de bathrooms es: 1
# La Varianza de bathrooms es: 0.55

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
# TODO

for n in sb:
    precio_max = int(sb_ds[sb_ds['level5'] == n]['price'].max())
    fila_precio_max = sb_ds[(sb_ds['level5'] == n) & (sb_ds['price'] == precio_max)]
    direccion_max_price = fila_precio_max['address'].values[0]
    print(f'{n}: {direccion_max_price}: {precio_max} $')
# Out:
# Fuenlabrada: Calle de Paulo Freire, 5, Fuenlabrada: 490000 $
# Leganés: Avenida Reina Sofía, Leganés: 650000 $
# Getafe: Getafe: 1050000 $
# Alcorcón: Calle Copenhague, 60, Alcorcón: 602800 $

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
# TODO
sb_ds = sb_ds.copy()
sb_ds['precio_norm'] = (sb_ds['price'] - sb_ds['price'].mean()) / sb_ds['price'].std()

plt.figure(figsize=(10, 5))

for n in sb:
    localidad = sb_ds[sb_ds['level5'] == n]
    plt.hist(localidad['precio_norm'], bins=20, label=n, alpha=0.5)

plt.title(f"Precio Promedio Normalizado Viviendas en Sur de Madrid")
plt.xlabel("Precio Normalizado")
plt.ylabel("Frecuencia")
plt.legend()
plt.show()

# %% [markdown]
# Se observa que la localidad de Getafe no solo es la presente la mayor cantidad de viviendas en venta, si no agrupa a las de mayor precio de la region sur de madrid

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# TODO
sb_ds = sb_ds.copy()
sb_ds['precio/mt2'] = sb_ds['price'] / sb_ds['surface']
alcorcon_data = sb_ds[sb_ds['level5'] == 'Alcorcón']['precio/mt2'].dropna()
getafe_data = sb_ds[sb_ds['level5'] == 'Getafe']['precio/mt2'].dropna()

plt.figure(figsize=(10, 5))

# Alcorcón
plt.subplot(1, 2, 1)
plt.boxplot(alcorcon_data)
plt.title("Precio por Metro Cuadrado en Alcorcón")
plt.xlabel("Alcorcón")
plt.ylabel("Precio por Metro Cuadrado")

# Getafe
plt.subplot(1, 2, 2)
plt.boxplot(getafe_data)
plt.title("Precio por Metro Cuadrado en Getafe")
plt.xlabel("Getafe")
plt.ylabel("Precio por Metro Cuadrado")

plt.show()

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
# TODO

sb_ds = sb_ds.copy()

plt.figure(figsize=(12, 6))

for n in sb:
    price = sb_ds[sb_ds['level5'] == n]['price']
    surface = sb_ds[sb_ds['level5'] == n]['surface']
    plt.scatter(surface, price, label=n)

plt.legend()
plt.title("Dispersión de Precio vs Superficie por Localidad")
plt.xlabel("Superficie")
plt.ylabel("Precio")
plt.show()

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in the question 14) (★★★★)
#
# Execute the following cell and then start coding in the next one. You must implement a simple code that transform the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
from ipyleaflet import Map, basemaps, Marker

# Map centred on (60 degrees latitude et -2.2 degrees longitude)
# Latitude, longitude
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 6
#       1 from ipyleaflet import Map, basemaps, Marker
#       3 # Map centred on (60 degrees latitude et -2.2 degrees longitude)
#       4 # Latitude, longitude
#       5 map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20,
# ----> 6     basemap=basemaps.Stamen.Terrain)
#       7 map
#
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:46, in Bunch.__getattr__(self, key)
#      44     return self.__getitem__(key)
# ...

# %%
## HERE: plot the coordinates of the estates

diccionario = {}
for index, row in sb_ds.iterrows():
    localidad = row['level5']
    lat = row['latitude']
    lon = row['longitude']
    diccionario['localidad'] = {'latitud': lat, 'longitud': lon}

## PUT HERE YOUR CODE:
    
for localidad, coords in diccionario.items():
    marker = Marker(location=(coords['latitud'], coords['longitud']), title=localidad)
    map.add_layer(marker)

map
# Out:
# Map(bottom=98956.0, center=[40.300476079749494, -3.7998962402343754], controls=(ZoomControl(options=['position…
